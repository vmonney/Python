# %% [markdown]
# # MNIST multilayer network

# %%
# Import libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise - Load and preprocess data
#
# > **Exercise**: Load the MNIST data. Split it into train, validation and test sets. Standardize the images. Define a `get_batches(X, y, batch_size)` function to generate random X/y batches of size `batch_size` using a Python generator.

# %%
# Load data
with np.load('mnist-60k.npz', allow_pickle=False) as npz_file:
    # Load items into a dictionnary
    mnist = dict(npz_file.items())
    
mnist['data'].shape
# Out:
# (60000, 784)

# %%
# Create train and validation sets
X_train, X_test, y_train, y_test = train_test_split(
    #Convert uint8 pixel values to float
    mnist['data'].astype(np.float32),
    mnist['labels'],
    test_size=10000, random_state=0)

# Split test into validation/test sets
X_valid, X_test, y_valid, y_test = train_test_split(
    X_test, y_test,
    test_size=5000, random_state=0
)

# Standardize
scaler = StandardScaler()
X_train_rescaled = scaler.fit_transform(X_train)
X_valid_rescaled = scaler.transform(X_valid)
X_test_rescaled = scaler.transform(X_test)

# %%
# Batch generator
def get_batches(X, y, batch_size):
    # Shuffle X,y
    shuffled_idx = np.arange(len(y)) #1,2,...,n
    np.random.shuffle(shuffled_idx)
    
    # Enumerate indexes by steps of batch_size
    # i: 0, b, 2b, 3b, 4b, .. where b is the batch size
    for i in range(0, len(y), batch_size):
        # Batch indexes
        batch_idx = shuffled_idx[i:i+batch_size]
        yield X[batch_idx], y[batch_idx]

# %% [markdown]
# ## Exercise - Create and train a multilayer network
#
# > **Exercise:** Create a multilayer neural network and train it using your batch generator. Evaluate the accuracy on the validation set after each epoch. Test different architectures and parameters. Evaluate your best network on the test set. Save the trained weights of the first fully connected layer in a variable.

# %% [markdown]
# ## Tensorflow implementation

# %%
# Create Tensorflow graph
# Create a new graph
graph = tf.Graph()

with graph.as_default():
    #Create placeholders
    X = tf.placeholder(dtype=tf.float32, shape=[None, 784])
    y = tf.placeholder(dtype=tf.int32, shape =[None])
    
    # First Hidden layer with 64 units
    hidden = tf.layers.dense(
    X, 64, activation = tf.nn.relu, # ReLU
    kernel_initializer = tf.variance_scaling_initializer(scale=2, seed=0),
    bias_initializer = tf.zeros_initializer(),
    name='hidden'
    )

    # Output layer
    logits = tf.layers.dense(
    hidden, 10, activation = None, #No activation function
    kernel_initializer = tf.variance_scaling_initializer(scale=1, seed=0),
    bias_initializer = tf.zeros_initializer(),
    name='output'
    )

# %% [markdown]
# ## Loss function and training operation

# %%
with graph.as_default():
    # Loss function: mean cross-entropy
    mean_ce = tf.reduce_mean(
        tf.nn.sparse_softmax_cross_entropy_with_logits(
            labels=y, logits=logits))
    
    # Gradient descent
    lr = tf.placeholder(dtype=tf.float32)
    gd = tf.train.GradientDescentOptimizer(learning_rate=lr)
    
    # Minimize cross-entropy
    train_op = gd.minimize(mean_ce)
    
    # Compute predictions and accuracy
    predictions = tf.argmax(logits, axis=1, output_type=tf.int32)
    is_correct = tf.equal(y, predictions)
    accuracy = tf.reduce_mean(tf.cast(is_correct, dtype=tf.float32))

# %%
with graph.as_default():
    # Get weights/biases of the first hidden layer
    with tf.variable_scope('hidden', reuse=True):
        W1 = tf.get_variable('kernel')
        b1 = tf.get_variable('bias')
        
    # Get weights/biases of the output layer
    with tf.variable_scope('output', reuse=True):
        W2 = tf.get_variable('kernel')
        b2 = tf.get_variable('bias')

# %%
# Validation accuracy
valid_acc_values = []

with tf.Session(graph=graph) as sess:
    # Initialize variables
    sess.run(tf.global_variables_initializer())
    
    # Set seed
    np.random.seed(0)
    
    # Train several epochs
    for epoch in range(50):
        # Accuracy values (train) after each batch
        batch_acc = []
        
        # Get batches of data
        for X_batch, y_batch in get_batches(X_train_rescaled, y_train, 64):
            # Run training and evaluate accuracy
            _, acc_value = sess.run([train_op, accuracy], feed_dict={
                X: X_batch,
                y: y_batch,
                lr: 0.01 # Learning rate
            })
            
            # Save accuracy (current batch)
            batch_acc.append(acc_value)
            
        # Evaluate validation accuracy
        valid_acc = sess.run(accuracy, feed_dict={
            X: X_valid_rescaled,
            y: y_valid
        })
        valid_acc_values.append(valid_acc)
        
        # Print progress
        print('Epoch {} - valid: {:.3f} train: {:.3f} (mean)'.format(epoch+1, valid_acc, np.mean(batch_acc)
        ))
        
    # Weights of the hidden and output layers
    weights_hidden = W1.eval()
    weights_output = W2.eval()
# Out:
# Epoch 1 - valid: 0.900 train: 0.812 (mean)
# Epoch 2 - valid: 0.919 train: 0.908 (mean)
# Epoch 3 - valid: 0.928 train: 0.924 (mean)
# Epoch 4 - valid: 0.936 train: 0.933 (mean)
# Epoch 5 - valid: 0.941 train: 0.940 (mean)
# Epoch 6 - valid: 0.946 train: 0.946 (mean)
# Epoch 7 - valid: 0.949 train: 0.949 (mean)
# Epoch 8 - valid: 0.950 train: 0.953 (mean)
# Epoch 9 - valid: 0.952 train: 0.956 (mean)
# Epoch 10 - valid: 0.953 train: 0.959 (mean)
# Epoch 11 - valid: 0.954 train: 0.961 (mean)
# Epoch 12 - valid: 0.955 train: 0.963 (mean)
# Epoch 13 - valid: 0.957 train: 0.965 (mean)
# Epoch 14 - valid: 0.959 train: 0.966 (mean)
# Epoch 15 - valid: 0.958 train: 0.968 (mean)
# Epoch 16 - valid: 0.960 train: 0.969 (mean)
# Epoch 17 - valid: 0.961 train: 0.971 (mean)
# Epoch 18 - valid: 0.960 train: 0.972 (mean)
# Epoch 19 - valid: 0.961 train: 0.973 (mean)
# Epoch 20 - valid: 0.963 train: 0.974 (mean)
# Epoch 21 - valid: 0.963 train: 0.975 (mean)
# Epoch 22 - valid: 0.965 train: 0.976 (mean)
# Epoch 23 - valid: 0.964 train: 0.977 (mean)
# Epoch 24 - valid: 0.965 train: 0.977 (mean)
# Epoch 25 - valid: 0.965 train: 0.978 (mean)
# Epoch 26 - valid: 0.965 train: 0.979 (mean)
# Epoch 27 - valid: 0.966 train: 0.980 (mean)
# Epoch 28 - valid: 0.965 train: 0.980 (mean)
# Epoch 29 - valid: 0.966 train: 0.981 (mean)
# Epoch 30 - valid: 0.966 train: 0.982 (mean)
# Epoch 31 - valid: 0.967 train: 0.982 (mean)
# Epoch 32 - valid: 0.966 train: 0.982 (mean)
# Epoch 33 - valid: 0.966 train: 0.983 (mean)
# Epoch 34 - valid: 0.967 train: 0.983 (mean)
# Epoch 35 - valid: 0.967 train: 0.984 (mean)
# Epoch 36 - valid: 0.967 train: 0.985 (mean)
# Epoch 37 - valid: 0.968 train: 0.985 (mean)
# Epoch 38 - valid: 0.968 train: 0.985 (mean)
# Epoch 39 - valid: 0.968 train: 0.986 (mean)
# Epoch 40 - valid: 0.967 train: 0.986 (mean)
# Epoch 41 - valid: 0.968 train: 0.987 (mean)
# Epoch 42 - valid: 0.968 train: 0.987 (mean)
# Epoch 43 - valid: 0.969 train: 0.988 (mean)
# Epoch 44 - valid: 0.968 train: 0.988 (mean)
# Epoch 45 - valid: 0.968 train: 0.988 (mean)
# Epoch 46 - valid: 0.969 train: 0.989 (mean)
# Epoch 47 - valid: 0.969 train: 0.989 (mean)
# Epoch 48 - valid: 0.968 train: 0.989 (mean)
# Epoch 49 - valid: 0.968 train: 0.989 (mean)
# Epoch 50 - valid: 0.968 train: 0.990 (mean)

# %% [markdown]
# ## Exercise - Visualize weights
#
# > **Exercise**: Plot the weights from the first fully connected layer (the templates) with the `imshow()` function.

# %%
# Create figure with 64 subplots
fig, axes = plt.subplots(nrows=8, ncols=8, figsize=(10,12))

# Plot weights of the 64 hidden units
for i, axis in enumerate(axes.flatten()):
    # Get weights of i-th hidden unit
    weights = weights_hidden[:, i]
    
    # Reshape into 28 by 28 array
    weights = weights.reshape(28,28)
    
    # Plot weights
    axis.set_title('unit {}'.format(i+1))
    axis.imshow(weights, cmap=plt.cm.gray_r) # Grayscale
    axis.get_xaxis().set_visible(False) # Disable x-axis
    axis.get_yaxis().set_visible(False) # Disable y-axis
    
plt.show()

# %% [markdown]
# ### Create several graphs

# %%
# Define graphs
simple_graph = tf.Graph()
complex_graph = tf.Graph()

with simple_graph.as_default():
    # ..

with complex_graph.as_default():
    # ..

# Use the graphs to run computations
with tf.Session(graph=simple_graph) as sess:
    # ..

with tf.Session(graph=complex_graph) as sess:
    # ..
# Out:
#   File "<ipython-input-57-f056700580b6>", line 8
#     with complex_graph.as_default():
#        ^
# IndentationError: expected an indented block
