# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import datasets
iris = datasets.load_iris()

# %%
np.linspace(0,5,9)
# Out:
# array([0.   , 0.625, 1.25 , 1.875, 2.5  , 3.125, 3.75 , 4.375, 5.   ])

# %%
# default value of linear spacing is 50 values
X = np.linspace(-np.pi, np.pi)
Y = np.sin(X) + np.cos(X)
plt.plot(X,Y, color='red', linewidth=2)
plt.xlim(-4,4)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], ['$-\pi$', '$-\pi/2$', '$0$', '$\pi/2$', '$\pi$'])
plt.title('The function $f(x)=\sin(x) + \cos(x)$');

# %%
X = np.linspace(-15, 15)
f1 = np.sin(X)/X
f2 = 2*np.sin(X)/X
f3 = 3*np.sin(X)/X
plt.plot(X,f1, color = 'blue', linestyle = '--', linewidth = 2.0, label = "$\sin(x)/x$")
plt.plot(X,f2, color = 'green', linestyle = '-.', linewidth = 2.0, label = "$2*\sin(x)/x$")
plt.plot(X, f3, color = 'red', marker='o', linewidth = 2.0, label = "$3*\sin(x)/x$")
plt.ylim(-1,3.5)
plt.yticks([-1, 0, 1, 2, 3])
plt.legend();

# %%
countries = ['USA', 'GB', 'China', 'Russia', 'Germany']
bronzes = np.array([38, 17, 26, 19, 15])
silvers = np.array([37, 23, 18, 17, 10])
golds = np.array([46, 27, 26, 19, 17])
total = np.array([121,67,70,55,42])
x_cor = np.arange(5)
plt.bar(x_cor, golds, color='gold', edgecolor='black', bottom=silvers+bronzes, label='gold medals')
plt.bar(x_cor, silvers, color='silver', edgecolor='black', bottom=bronzes, label='silver medals')
plt.bar(x_cor, bronzes, color='#CD853F', edgecolor='black', label = 'bronze medals')
plt.xticks(x_cor, countries)
plt.ylabel("Medals")
plt.xlabel("Coutries")
plt.title("2016 Olypics Medals: Top Countries")
plt.legend(loc='upper right');

# %%
iris_df = pd.DataFrame(iris['data'], columns = iris['feature_names'])
iris_df['species'] = iris['target']
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
iris_df['species'].unique()
# Out:
# array([0, 1, 2])

# %%
species = ["Iris " + x for x in iris.target_names]
colors = ['red', 'orange', 'green']

# %%
for i in range(iris_df['species'].nunique()):
    species_df = iris_df[iris_df['species'] == i]
    plt.scatter(species_df['sepal length (cm)'], species_df['petal length (cm)'], c = colors[i], label = species[i])
plt.xlabel('sepal length (cm)')
plt.ylabel('petal length (cm)')
plt.title('Iris dataset: petal length vs sepal length')
plt.legend(loc = 'lower right');

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.distplot(iris['sepal_length']);

# %%
sns.regplot(iris.sepal_length, iris.petal_length)
plt.title("A Title")
plt.ylabel("y-label")
plt.xlabel("x-label")
sns.set_style('white')
plt.show()

# %%
sns.pairplot(iris, kind='reg');

# %%
my_palette=["#95a5a6", "#e74c3c", "#34495e"]
sns.pairplot(iris, x_vars = ['sepal_length'], y_vars = ['petal_length'], height = 10, hue='species', palette = my_palette)
plt.title('The Iris data set: petal length vs sepal length');

# %%
grid = sns.FacetGrid(iris, col='species')
grid = grid.map(plt.scatter, "sepal_length", "petal_length");

# %%
my_palette = ["#F67A92", "#37A42E", "#30A0DB"]
sns.violinplot(x = iris.species, y= iris.petal_length, palette= my_palette)
plt.title("A violin plot of petal length")
plt.show()

# %%
sns.swarmplot(x = "species", y='sepal_length', data = iris, palette = 'pastel')
plt.title("A swarmplot of sepal length")
# Out:
# Text(0.5, 1.0, 'A swarmplot of sepal length')
